# %%
# parsing a graphql instagram

import json
import requests

tag = 'kabinetindonesiamaju'
url = 'https://www.instagram.com/explore/tags/' + tag + '/?__a=1'
'''
keys = ['id', 'owner', 'taken_at_timestamp', 'text', 'count',
        'video_view_count',
        'edge_media_to_comment',
        'edge_media_to_caption',
        'edge_liked_by',
        'edge_media_preview_like']
'''

keys = ['text']


def jprint(data_dict):
  print(json.dumps(data_dict, indent = 4))

#Grab the data
def get_ig_page(url, session=None):
  print(url)
  session = session or requests.Session()

  r = session.get(url)
  r_code = r.status_code
  print(r_code)

  if r_code == requests.codes.ok:
    return r
  else:
    return None

ig_data_dict = get_ig_page(url)


if ig_data_dict is not None:
  ig_data_dict = ig_data_dict.json()     #complete data crawled with graphql keyword
#  jprint(ig_data_dict)


  graphql = ig_data_dict.get('graphql', None) #removing graphql keyword
#  jprint(graphql)

  hashtag = graphql.get('hashtag', None) #removing hashtag keyword
#  jprint(hashtag)

  #get name
  name = hashtag.get('name', None) 
  jprint(name)
 
  #get is_top_media_only 
  is_top_media_only = hashtag.get('is_top_media_only', None)
  jprint(is_top_media_only)

  #get profile_pic_url
  profile_pic_url = hashtag.get('profile_pic_url', None)
  jprint(profile_pic_url)

  #removing edge_hashtag_to_media keyword
  edge_hashtag_to_media = hashtag.get('edge_hashtag_to_media', None)
#  jprint(edge_hashtag_to_media)

  #get count
  count = edge_hashtag_to_media.get('count', None)
  jprint(count)

  #get page info
  page_info = edge_hashtag_to_media.get('page_info', None)
  jprint(page_info)

  #remove edges keyword
#  edges = edge_hashtag_to_media.dumps('edges', None)
#  jprint(edges)

  #get node
  node = edge_hashtag_to_media.get('edges', None)
#  jprint(node)

  print (len(node))

#  a = json.dumps(node)
#  print(a)

'''
for team in json_dict['teams']:
    print team['_links']['fixtures']['href']
'''

for post in edge_hashtag_to_media['edges']:
    print(post['node']['id'])
    
'''
for post in edge_hashtag_to_media:
    for key in keys:
#      print(key.upper(), ':', post.get(key))
      print(key, ':', post.get(key))  
else:
    print('Oops something went wrong!')    

'''
# Out:
# https://www.instagram.com/explore/tags/kabinetindonesiamaju/?__a=1
# 200
# "kabinetindonesiamaju"
# false
# "https://instagram.fbdo4-1.fna.fbcdn.net/vp/1a885a1db0a883b68f112dc75cf9cee9/5E4AF121/t51.2885-15/e35/s150x150/72898284_152681689274980_3840659124078273825_n.jpg?_nc_ht=instagram.fbdo4-1.fna.fbcdn.net&_nc_cat=104"
# 7128
# {
#     "has_next_page": true,
#     "end_cursor": "QVFEc2R6WDVKWWUtel9nT25MdkFmUUl1OTRUSzVUMTJaSUlHOHFtRzNWZzluQnNYU0x2YkZTZGRtLXV4bFpDcUdOQXBTc3FaLVNoQU0tbmM3VVFaYk9oXw=="
# }
# 51
# 2161804887816481971
# 2161805166127812405
# 2161803721432684574
# 2161804121586713657
# 2161803384605093184
# 2161803518611174770
# 2161803046920074616
# 2161802674593624116
# 2161799915261887478
# 2161800545429784961
# 2161801817621988617
# 2161801645711788813
# 2161800899830655146
# 2161800375424978098
# 2161799445312717274
# 2161799329516398382
# 2161799233357914254
# 2161799154607404703
# 2161799137929001758
# 2161799043540365556
# 2161798964159136169
# 2161798945572312088
# ...

# %%
# parsing a graphql instagram
# CG - last updated 2 May 2018

import json
import requests

tag = 'kabinetindonesiamaju'
url = 'https://www.instagram.com/explore/tags/' + tag + '/?__a=1'
'''
keys = ['id', 'owner', 'taken_at_timestamp', 'text', 'count',
        'video_view_count',
        'edge_media_to_comment',
        'edge_media_to_caption',
        'edge_liked_by',
        'edge_media_preview_like']
'''

keys = ['text']


def jprint(data_dict):
  print(json.dumps(data_dict, indent = 4))

#Grab the data
def get_ig_page(url, session=None):
  print(url)
  session = session or requests.Session()

  r = session.get(url)
  r_code = r.status_code
  print(r_code)

  if r_code == requests.codes.ok:
    return r
  else:
    return None

ig_data_dict = get_ig_page(url)


if ig_data_dict is not None:
  ig_data_dict = ig_data_dict.json()     #complete data crawled with graphql keyword
#  jprint(ig_data_dict)


  graphql = ig_data_dict.get('graphql', None) #removing graphql keyword
#  jprint(graphql)

  hashtag = graphql.get('hashtag', None) #removing hashtag keyword
#  jprint(hashtag)

  #get name
  name = hashtag.get('name', None) 
  jprint(name)
 
  #get is_top_media_only 
  is_top_media_only = hashtag.get('is_top_media_only', None)
  jprint(is_top_media_only)

  #get profile_pic_url
  profile_pic_url = hashtag.get('profile_pic_url', None)
  jprint(profile_pic_url)

  #removing edge_hashtag_to_media keyword
  edge_hashtag_to_media = hashtag.get('edge_hashtag_to_media', None)
#  jprint(edge_hashtag_to_media)

  #get count
  count = edge_hashtag_to_media.get('count', None)
  jprint(count)

  #get page info
  page_info = edge_hashtag_to_media.get('page_info', None)
  jprint(page_info)

  #remove edges keyword
#  edges = edge_hashtag_to_media.dumps('edges', None)
#  jprint(edges)

  #get node
  node = edge_hashtag_to_media.get('edges', None)
#  jprint(node)

  print (len(node))

#  a = json.dumps(node)
#  print(a)

'''
for team in json_dict['teams']:
    print team['_links']['fixtures']['href']
'''
c = 0
for post in edge_hashtag_to_media['edges']:
    get_text = post['node']['edge_media_to_caption']['edges']
#    print(post['node']['edge_media_to_caption']['edges'])
#    print(get_text)
    for post in get_text:
        c = c + 1
        print(post['node']['text'] , c)
# Out:
# https://www.instagram.com/explore/tags/kabinetindonesiamaju/?__a=1
# 200
# "kabinetindonesiamaju"
# false
# "https://instagram.fcgk8-1.fna.fbcdn.net/vp/f8b8a578b3847e8968123b91597ad64b/5E656FE2/t51.2885-15/e35/c65.0.949.949a/s150x150/75266929_693658614460091_2699463765027552938_n.jpg?_nc_ht=instagram.fcgk8-1.fna.fbcdn.net&_nc_cat=1"
# 4381
# {
#     "has_next_page": true,
#     "end_cursor": "QVFCWFRtRlRKMXowV2h6YVB6b21MWlJiV19TaDNQdHhrZFJGYTQ4cGFTcGFEUzA0MFcyNmZqbjdibW1tNjlVeFBhaHBEODJ3a0Q3LTFrMmJYa2ZUOUhtUA=="
# }
# 55
# Keluarga besar Satpol PP dan Damkar Kota Mojokerto mengucapkan selamat dan sukses kepada Jenderal Polisi (Purn.) Prof. Drs. H. Muhammad Tito Karnavian, M.A., Ph.D. sebagai Menteri Dalam Negeri  periode 2019-2024
# .
# #kabinetindonesiamaju #pelantikanmenteri #pelantikan 1
# ...

# %%
# parsing a graphql instagram

import json
import requests

tag = 'kabinetindonesiamaju'
url = 'https://www.instagram.com/explore/tags/' + tag + '/?__a=1'
'''
keys = ['id', 'owner', 'taken_at_timestamp', 'text', 'count',
        'video_view_count',
        'edge_media_to_comment',
        'edge_media_to_caption',
        'edge_liked_by',
        'edge_media_preview_like']
'''

keys = ['text']


def jprint(data_dict):
  print(json.dumps(data_dict, indent = 4))

#Grab the data
def get_ig_page(url, session=None):
  print(url)
  session = session or requests.Session()

  r = session.get(url)
  r_code = r.status_code
  print(r_code)

  if r_code == requests.codes.ok:
    return r
  else:
    return None

ig_data_dict = get_ig_page(url)


if ig_data_dict is not None:
  ig_data_dict = ig_data_dict.json()     #complete data crawled with graphql keyword
#  jprint(ig_data_dict)


  graphql = ig_data_dict.get('graphql', None) #removing graphql keyword
#  jprint(graphql)

  hashtag = graphql.get('hashtag', None) #removing hashtag keyword
#  jprint(hashtag)

  #get name
  name = hashtag.get('name', None) 
  jprint(name)
 
  #get is_top_media_only 
  is_top_media_only = hashtag.get('is_top_media_only', None)
  jprint(is_top_media_only)

  #get profile_pic_url
  profile_pic_url = hashtag.get('profile_pic_url', None)
  jprint(profile_pic_url)

  #removing edge_hashtag_to_media keyword
  edge_hashtag_to_media = hashtag.get('edge_hashtag_to_media', None)
#  jprint(edge_hashtag_to_media)

  #get count
  count = edge_hashtag_to_media.get('count', None)
  jprint(count)

  #get page info
  page_info = edge_hashtag_to_media.get('page_info', None)
  jprint(page_info)

  #remove edges keyword
#  edges = edge_hashtag_to_media.dumps('edges', None)
#  jprint(edges)

  #get node
  node = edge_hashtag_to_media.get('edges', None)
#  jprint(node)

  print (len(node))

#  a = json.dumps(node)
#  print(a)

'''
for team in json_dict['teams']:
    print team['_links']['fixtures']['href']
'''
data_file = "data_file.txt"
data = open(data_file, "w")


count = 0

for post in edge_hashtag_to_media['edges']:
    get_text = post['node']['edge_media_to_caption']['edges']
#    print(post['node']['edge_media_to_caption']['edges'])
#    print(get_text)
   
    for post in get_text:
        print(post['node']['text'])
        data.write(post['node']['text'])
        count = count +1
        
print("Total nodes: " + str(count))
# Out:
# https://www.instagram.com/explore/tags/kabinetindonesiamaju/?__a=1
# 200
# "kabinetindonesiamaju"
# false
# "https://instagram.fbdo4-1.fna.fbcdn.net/vp/1a885a1db0a883b68f112dc75cf9cee9/5E4AF121/t51.2885-15/e35/s150x150/72898284_152681689274980_3840659124078273825_n.jpg?_nc_ht=instagram.fbdo4-1.fna.fbcdn.net&_nc_cat=104"
# 7128
# {
#     "has_next_page": true,
#     "end_cursor": "QVFBX2M4RmRWSkV0NXE4V2xFS2ZWczhyUGdsR1ZDZUpIR0NOT1BaaWZNS1NYSGxsVVZaOGhCakVyZ0F2TG5CQlUtR01VLW9JbUNJWXM0aUxOSjhUVVhBWQ=="
# }
# 51
# Penonton, mohon bersabar! Jangan iri!
# Hahaha
#
# https://www.google.com/amp/s/amp.suara.com/news/2019/10/14/161245/viral-video-tiktok-anggota-dpr-lora-fadil-dan-3-istrinya
# __________
# Follow 👉 @cakmid_bookstore
# Follow 👉 @cakmid_bookstore
# __________
# #entahapayangmerasukimu #menteri #kabinetindonesiamaju #dprri #lorafadil #jember #tiktok #legislatif #poligami #istri
# __________
# ...

# %%
# parsing a graphql instagram
# CG - last updated 2 May 2018

import json
import requests
import re
from collections import Counter

tag = 'kabinetindonesiamaju'
url = 'https://www.instagram.com/explore/tags/' + tag + '/?__a=1'
'''
keys = ['id', 'owner', 'taken_at_timestamp', 'text', 'count',
        'video_view_count',
        'edge_media_to_comment',
        'edge_media_to_caption',
        'edge_liked_by',
        'edge_media_preview_like']
'''

stop_words = ['is', 'that', 'and', 'this', 'or', 'these', 'those', 'https', 'graphql', 'hashtag', 'instagram', 'fna',
             'fbcdn', 'net', 'jpg', 'src', 'the', 'yang', 'dan', 'untuk', 'dengan', 'pada', 'ini', 'akan', 'dari', 
              'kami', 'kalian', 'kita']

keys = ['text']


def jprint(data_dict):
  print('DISINI - '+json.dumps(data_dict, indent = 4))

#Grab the data
def get_ig_page(url, session=None):
  print('INI URL - '+url)
  session = session or requests.Session()

  r = session.get(url)
  r_code = r.status_code
  print('INI R_CODE - '+str(r_code))

  if r_code == requests.codes.ok:
    return r
  else:
    return None

ig_data_dict = get_ig_page(url)
print('-------- '+str(ig_data_dict))

if ig_data_dict is not None:
  ig_data_dict = ig_data_dict.json()     #complete data crawled with graphql keyword
#  jprint(ig_data_dict)


  graphql = ig_data_dict.get('graphql', None) #removing graphql keyword
#  jprint(graphql)

  hashtag = graphql.get('hashtag', None) #removing hashtag keyword
#  jprint(hashtag)

  #get name
  name = hashtag.get('name', None) 
  jprint(name)
 
  #get is_top_media_only 
  is_top_media_only = hashtag.get('is_top_media_only', None)
  jprint(is_top_media_only)

  #get profile_pic_url
  profile_pic_url = hashtag.get('profile_pic_url', None)
  jprint(profile_pic_url)

  #removing edge_hashtag_to_media keyword
  edge_hashtag_to_media = hashtag.get('edge_hashtag_to_media', None)
#  jprint(edge_hashtag_to_media)

  #get count
  count = edge_hashtag_to_media.get('count', None)
  jprint(count)

  #get page info
  page_info = edge_hashtag_to_media.get('page_info', None)
  jprint(page_info)

  #remove edges keyword
#  edges = edge_hashtag_to_media.dumps('edges', None)
#  jprint(edges)

  #get node
  node = edge_hashtag_to_media.get('edges', None)
#  jprint(node)

  print (len(node))

#  a = json.dumps(node)
#  print(a)

'''
for team in json_dict['teams']:
    print team['_links']['fixtures']['href']
'''

counter = 0
text = ''
for post in edge_hashtag_to_media['edges']:
    get_text = post['node']['edge_media_to_caption']['edges']
#    print(post['node']['edge_media_to_caption']['edges'])
#    print(get_text)
    for post in get_text:
        #print(post['node']['text'])
        text += post['node']['text']
        counter += 1

text_string = text.lower() #convert input text to lower case
match_pattern = re.findall(r'\b[a-z]{3,15}\b', text_string) #regex for removing symbols

popularKeyword = []
for word in match_pattern:
    if word not in stop_words:
        popularKeyword.append(word)
        #count = frequency.get(word, 0)
        #frequency[word] = count + 1
    
print('jumlah node: ' + str(counter))
print(Counter(popularKeyword).most_common(20))
#print(frequency)
# Out:
# INI URL - https://www.instagram.com/explore/tags/kabinetindonesiamaju/?__a=1
# INI R_CODE - 200
# -------- <Response [200]>
# DISINI - "kabinetindonesiamaju"
# DISINI - false
# DISINI - "https://instagram.fbdo4-1.fna.fbcdn.net/vp/1a885a1db0a883b68f112dc75cf9cee9/5E4AF121/t51.2885-15/e35/s150x150/72898284_152681689274980_3840659124078273825_n.jpg?_nc_ht=instagram.fbdo4-1.fna.fbcdn.net&_nc_cat=104"
# DISINI - 7130
# DISINI - {
#     "has_next_page": true,
#     "end_cursor": "QVFENzlkQmxaSVUydVJQN0JUdTloSDM2clBYVmpRdWVoazdTVkY0OXhfY3p1TXNCWGxKVFBsd2syOWt0eldJeEJfV3FKNC1uMFlpQnl2YVdKRFdkWjBETQ=="
# }
# 51
# jumlah node: 51
# [('presiden', 34), ('menteri', 30), ('jokowi', 29), ('indonesia', 24), ('kabinet', 22), ('maju', 16), ('dalam', 16), ('negara', 15), ('rapat', 14), ('ada', 11), ('adalah', 11), ('kerja', 10), ('bisa', 9), ('wakil', 9), ('com', 9), ('lebih', 9), ('baru', 9), ('follow', 8), ('serikatnews', 8), ('hari', 8)]

# %%
# parsing a graphql instagram
# CG - last updated 2 May 2018

import json
import requests
import re
from collections import Counter

tag = 'telkomuniversity'
url = 'https://www.instagram.com/explore/tags/' + tag + '/?__a=1'
'''
keys = ['id', 'owner', 'taken_at_timestamp', 'text', 'count',
        'video_view_count',
        'edge_media_to_comment',
        'edge_media_to_caption',
        'edge_liked_by',
        'edge_media_preview_like']
'''

stop_words = ['is', 'that', 'and', 'this', 'or', 'these', 'those', 'https', 'graphql', 'hashtag', 'instagram', 'fna',
             'fbcdn', 'net', 'jpg', 'src', 'the', 'yang', 'dan', 'untuk', 'dengan', 'pada', 'ini', 'akan', 'dari', 
              'kami', 'kalian', 'kita']

keys = ['text']


def jprint(data_dict):
  print('DISINI - '+json.dumps(data_dict, indent = 4))

#Grab the data
def get_ig_page(url, session=None):
#  print('INI URL - '+url)
  session = session or requests.Session()

  r = session.get(url)
  r_code = r.status_code
#  print('INI R_CODE - '+str(r_code))

  if r_code == requests.codes.ok:
    return r
  else:
    return None

ig_data_dict = get_ig_page(url)
# print('-------- '+str(ig_data_dict))

if ig_data_dict is not None:
  ig_data_dict = ig_data_dict.json()     #complete data crawled with graphql keyword
#  jprint(ig_data_dict)


  graphql = ig_data_dict.get('graphql', None) #removing graphql keyword
#  jprint(graphql)

  hashtag = graphql.get('hashtag', None) #removing hashtag keyword
#  jprint(hashtag)

  #get name
  name = hashtag.get('name', None) 
#  jprint(name)
 
  #get is_top_media_only 
  is_top_media_only = hashtag.get('is_top_media_only', None)
#  jprint(is_top_media_only)

  #get profile_pic_url
  profile_pic_url = hashtag.get('profile_pic_url', None)
#  jprint(profile_pic_url)

  #removing edge_hashtag_to_media keyword
  edge_hashtag_to_media = hashtag.get('edge_hashtag_to_media', None)
#  jprint(edge_hashtag_to_media)

  #get count
  count = edge_hashtag_to_media.get('count', None)
#  jprint(count)

  #get page info
  page_info = edge_hashtag_to_media.get('page_info', None)
#  jprint(page_info)

  #remove edges keyword
#  edges = edge_hashtag_to_media.dumps('edges', None)
#  jprint(edges)

  #get node
  node = edge_hashtag_to_media.get('edges', None)
#  jprint(node)

#  print (len(node))

#  a = json.dumps(node)
#  print(a)

'''
for team in json_dict['teams']:
    print team['_links']['fixtures']['href']
'''

counter = 0
text = 0
list = []
dict = {}

for post in edge_hashtag_to_media['edges']:
    get_id = post['node']['id']
    get_like = post['node']['edge_liked_by']['count']
#    print(get_id , get_like)
    
    dict[get_id] = get_like

urut =sorted(dict.items(), key = lambda x : x[1],reverse=True)
#print(urut)

listurut = []
listkey = []
listvalue = []

for i in range(6):
#    print((urut[i]))
#    print(type(urut[i]))
#    print ((urut[i])[0])
    listkey.append((urut[i])[0])
#    listurut.append(urut[i])
#    print ((urut[i])[1])
    listvalue.append((urut[i])[1])
print(listkey)
print(listvalue)


import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(listkey))
performance = listvalue

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, listkey)
plt.ylabel('jumlah like')
plt.title('matilampu')

plt.show()
# Out:
# ['2160847888354179795', '2160972783109889884', '2160833606438847683', '2160877507976348521', '2160842773249519843', '2160931292667997885']
# [572, 504, 285, 265, 258, 153]

# %%
# parsing a graphql instagram


import json
import requests
import re
from collections import Counter

tag = 'kabinetindonesiamaju'
url = 'https://www.instagram.com/explore/tags/' + tag + '/?__a=1'
'''
keys = ['id', 'owner', 'taken_at_timestamp', 'text', 'count',
        'video_view_count',
        'edge_media_to_comment',
        'edge_media_to_caption',
        'edge_liked_by',
        'edge_media_preview_like']
'''

stop_words = ['is', 'that', 'and', 'this', 'or', 'these', 'those', 'https', 'graphql', 'hashtag', 'instagram', 'fna',
             'fbcdn', 'net', 'jpg', 'src', 'the', 'yang', 'dan', 'untuk', 'dengan', 'pada', 'ini', 'akan', 'dari', 
              'kami', 'kalian', 'kita']

keys = ['text']


def jprint(data_dict):
  print('DISINI - '+json.dumps(data_dict, indent = 4))

#Grab the data
def get_ig_page(url, session=None):
#  print('INI URL - '+url)
  session = session or requests.Session()

  r = session.get(url)
  r_code = r.status_code
#  print('INI R_CODE - '+str(r_code))

  if r_code == requests.codes.ok:
    return r
  else:
    return None

ig_data_dict = get_ig_page(url)
# print('-------- '+str(ig_data_dict))

if ig_data_dict is not None:
  ig_data_dict = ig_data_dict.json()     #complete data crawled with graphql keyword
#  jprint(ig_data_dict)


  graphql = ig_data_dict.get('graphql', None) #removing graphql keyword
#  jprint(graphql)

  hashtag = graphql.get('hashtag', None) #removing hashtag keyword
#  jprint(hashtag)

  #get name
  name = hashtag.get('name', None) 
#  jprint(name)
 
  #get is_top_media_only 
  is_top_media_only = hashtag.get('is_top_media_only', None)
#  jprint(is_top_media_only)

  #get profile_pic_url
  profile_pic_url = hashtag.get('profile_pic_url', None)
#  jprint(profile_pic_url)

  #removing edge_hashtag_to_media keyword
  edge_hashtag_to_media = hashtag.get('edge_hashtag_to_media', None)
#  jprint(edge_hashtag_to_media)

  #get count
  count = edge_hashtag_to_media.get('count', None)
#  jprint(count)

  #get page info
  page_info = edge_hashtag_to_media.get('page_info', None)
#  jprint(page_info)

  #remove edges keyword
#  edges = edge_hashtag_to_media.dumps('edges', None)
#  jprint(edges)

  #get node
  node = edge_hashtag_to_media.get('edges', None)
#  jprint(node)

#  print (len(node))

#  a = json.dumps(node)
#  print(a)

'''
for team in json_dict['teams']:
    print team['_links']['fixtures']['href']
'''

counter = 0
text = 0
list = []
dict = {}

for post in edge_hashtag_to_media['edges']:
    get_id = post['node']['id']
    get_like = post['node']['edge_liked_by']['count']
#    print(get_id , get_like)
    
    dict[get_id] = get_like

urut =sorted(dict.items(), key = lambda x : x[1],reverse=True)
#print(urut)

listurut = []
listkey = []
listvalue = []

for i in range(6):
#    print((urut[i]))
#    print(type(urut[i]))
#    print ((urut[i])[0])
    listkey.append((urut[i])[0])
#    listurut.append(urut[i])
#    print ((urut[i])[1])
    listvalue.append((urut[i])[1])
print(listkey)
print(listvalue)


import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(listkey))
performance = listvalue


plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, listkey)
plt.xlabel('Status')
plt.ylabel('jumlah like')
plt.title('kabinet')

plt.show()

# Plotpie
explode = (0.1, 0.1, 0.1, 0.5, 0, 0)  # explode 1st slice
plt.pie(listvalue,labels=listkey,explode=explode,
autopct='%.1f', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
# Out:
# ['2161800899830655146', '2161799915261887478', '2161822276010803844', '2161783540513894877', '2161813911729186411', '2161803384605093184']
# [2259, 1460, 660, 411, 341, 71]

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time
import re
from urllib.request import urlopen
import json
from pandas.io.json import json_normalize
import pandas as pd, numpy as np
